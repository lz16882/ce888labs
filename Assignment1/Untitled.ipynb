# %%
task1 = []
with open('qa1_single-supporting-fact_train.txt') as inputfile:
    for line in inputfile:
        task1.append(line.strip().split('\t'))
task2 = []

with open('qa2_two-supporting-facts_train.txt') as inputfile:
    for line in inputfile:
        task2.append(line.strip().split('\t'))
        
task3 = []
with open('qa3_three-supporting-facts_train.txt') as inputfile:
    for line in inputfile:
        task3.append(line.strip().split('\t'))
        
task4 = []
with open('qa4_two-arg-relations_train.txt') as inputfile:
    for line in inputfile:
        task4.append(line.strip().split('\t'))
        
task5 = []
with open('qa5_three-arg-relations_train.txt') as inputfile:
    for line in inputfile:
        task5.append(line.strip().split('\t'))
        
task6 = []
with open('qa6_yes-no-questions_train.txt') as inputfile:
    for line in inputfile:
        task6.append(line.strip().split('\t'))
        
task7 = []
with open('qa7_counting_train.txt') as inputfile:
    for line in inputfile:
        task7.append(line.strip().split('\t'))
        
task8 = []
with open('qa8_lists-sets_train.txt') as inputfile:
    for line in inputfile:
        task8.append(line.strip().split('\t'))
        
task9 = []
with open('qa9_simple-negation_train.txt') as inputfile:
    for line in inputfile:
        task9.append(line.strip().split('\t'))
        
task10 = []
with open('qa10_indefinite-knowledge_train.txt') as inputfile:
    for line in inputfile:
        task10.append(line.strip().split('\t'))

# %%
task11 = []
with open('qa11_basic-coreference_train.txt') as inputfile:
    for line in inputfile:
        task11.append(line.strip().split('\t'))
        
task12 = []
with open('qa12_conjunction_train.txt') as inputfile:
    for line in inputfile:
        task12.append(line.strip().split('\t'))
        
task13 = []
with open('qa13_compound-coreference_train.txt') as inputfile:
    for line in inputfile:
        task13.append(line.strip().split('\t'))
        
task14 = []
with open('qa14_time-reasoning_train.txt') as inputfile:
    for line in inputfile:
        task14.append(line.strip().split('\t'))

task15 = []
with open('qa15_basic-deduction_train.txt') as inputfile:
    for line in inputfile:
        task15.append(line.strip().split('\t'))
        
task16 = []
with open('qa16_basic-induction_train.txt') as inputfile:
    for line in inputfile:
        task16.append(line.strip().split('\t'))
        
task17 = []
with open('qa17_positional-reasoning_train.txt') as inputfile:
    for line in inputfile:
        task17.append(line.strip().split('\t'))
        
task18 = []
with open('qa18_size-reasoning_train.txt') as inputfile:
    for line in inputfile:
        task18.append(line.strip().split('\t'))
        
task19 = []
with open('qa19_path-finding_test.txt') as inputfile:
    for line in inputfile:
        task19.append(line.strip().split('\t'))
        
task20 = []
with open('qa19_path-finding_train.txt') as inputfile:
    for line in inputfile:
        task20.append(line.strip().split('\t'))
